# %%
import pandas as pd

# %%
accidentDF = pd.read_csv("US_Accidents_Dec20_updated.csv")

# %%
accidentDF
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0        A-2716600         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1        A-2716601         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2        A-2716602         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3        A-2716603         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 4        A-2716604         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# ...            ...       ...                  ...                  ...
# 1516059  A-4239402         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 1516060  A-4239403         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 1516061  A-4239404         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 1516062  A-4239405         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 1516063  A-4239406         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat  Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ...

# %%
accidentDF.isnull().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1046095
# Street                         0
# Side                           0
# City                          83
# County                         0
# State                          0
# Zipcode                      935
# Country                        0
# Timezone                    2302
# Airport_Code                4248
# Weather_Timestamp          30264
# Temperature(F)             43033
# Wind_Chill(F)             449316
# Humidity(%)                45509
# Pressure(in)               36274
# Visibility(mi)             44211
# Wind_Direction             41858
# Wind_Speed(mph)           128862
# ...

# %%
for col in accidentDF.columns:
    if accidentDF[col].isnull().sum() >= 100000:
        del accidentDF[col]

# %%
accidentDF.isnull().sum()
# Out:
# ID                           0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# End_Lat                      0
# End_Lng                      0
# Distance(mi)                 0
# Description                  0
# Street                       0
# Side                         0
# City                        83
# County                       0
# State                        0
# Zipcode                    935
# Country                      0
# Timezone                  2302
# Airport_Code              4248
# Weather_Timestamp        30264
# Temperature(F)           43033
# Humidity(%)              45509
# Pressure(in)             36274
# Visibility(mi)           44211
# Wind_Direction           41858
# Weather_Condition        44007
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# ...

# %%
redundant_attributes = ["Weather_Timestamp", "Wind_Direction", "Timezone"]
for val in pita_attributes:
    del accidentDF[val]

# %%
accidentDF.isnull().sum()
# Out:
# ID                           0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# End_Lat                      0
# End_Lng                      0
# Distance(mi)                 0
# Description                  0
# Street                       0
# Side                         0
# City                        83
# County                       0
# State                        0
# Zipcode                    935
# Country                      0
# Temperature(F)           43033
# Humidity(%)              45509
# Pressure(in)             36274
# Visibility(mi)           44211
# Weather_Condition        44007
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# Railway                      0
# Roundabout                   0
# ...

# %%
pita_values = ["Temperature(F)", "Humidity(%)", "Pressure(in)", "Visibility(mi)", "Wind", "Weather_Condition"]
